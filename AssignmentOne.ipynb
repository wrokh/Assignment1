# %% [markdown]
# **Assignment One**
# Assignment by Eadan (Daisy) Gibb and Elliot Barr

# %% [markdown]
# ## 1 — Look at the data before you compute with it
#
# Good practice: plot raw data and confirm it is sane *before* any analysis.

# %% [markdown]
# ### (a)
#
# Plot the three position components $x, y, z$ against time. Use Earth radii for position and hours for time so the plot is readable.

# %%
# (a) plot x, y, z vs time (Earth radii, hours)

# %% [markdown]
# ### (b)
#
# Plot the orbit projected onto the XY and XZ planes.

# %%
# (b) plot orbit projections: XY plane and XZ plane

# %% [markdown]
# ### (c)
#
# Does this look like a plausible THEMIS-D orbit? Give two or three concrete reasons — think about the period, the shape, the range of $r$, and how close it stays to the equatorial plane.
#
# *Your answer:*

# %% [markdown]
# ## 2 — Energy conservation, with a 3-point derivative
#
# Compute total energy per unit mass and test whether it is conserved, using a point-mass ("monopole") Earth potential $\phi = -\mu/r$ and your 3-point central difference for velocity.
#
# - Convert km→m and hours→seconds **once**, right after loading.
# - Use at least five significant figures for constants: $\mu = 3.98600440 \times 10^{14}\ \mathrm{m^3/s^2}$.
# - Watch the sign on the potential.
# - Use `trim_edges` so KE, PE and $t$ describe the same instants.

# %%
# unit conversions (km->m, hours->s); compute KE, PE, E (monopole) with 3-point derivative; trim_edges

# %% [markdown]
# ### (a)
#
# Plot KE, PE and total $E = KE + PE$ (all per unit mass) on one axes, against time.

# %%
# (a) plot KE, PE, E on one axes vs time

# %% [markdown]
# ### (b)
#
# Plot total $E$ alone, on its own autoscaled axes so you can see its structure.

# %%
# (b) plot E alone, autoscaled

# %% [markdown]
# > ⛔ **STOP — discuss (c) with your group before going further**

# %% [markdown]
# ### (c)
#
# This data comes from a high-accuracy NASA orbit propagator. Does your plot in (b) demonstrate conservation of energy? If not, what do you think went wrong — the physics, or your numerics? Write a few sentences of your group's discussion.
#
# *Graded for evidence of discussion, not for being right. Genuinely argue about it.*
#
# *Group discussion:*

# %% [markdown]
# ## 3 — Improve the numerics: raise the order

# %% [markdown]
# ### (a)
#
# Recompute $E(t)$ using your 3-, 5- and 7-point stencils. Plot all three on one axes.

# %%
# (a) recompute E(t) with 3-, 5-, and 7-point stencils; plot together

# %% [markdown]
# ### (b)
#
# Did raising the order flatten $E(t)$? Explain why, in terms of truncation error and its order of accuracy. Which of the three error sources from Unit 1 did this step reduce?
#
# *Your answer:*

# %% [markdown]
# ## 4 — Improve the physics: a non-spherical Earth
#
# Even at 7-point order, $E(t)$ will not be flat. Earth's rotation gives it an equatorial bulge, so its potential is not quite that of a point mass. A better model (monopole + quadrupole):
#
# $$\phi = -\frac{\mu}{r} + \frac{J_2}{2r^5}\left(3z^2 - r^2\right), \qquad J_2 = 1.75553 \times 10^{25}\ \mathrm{m^5/s^2}$$
#
# with $r$ the radial distance and $z$ the height above the equatorial plane (GEI $z$).

# %% [markdown]
# ### (a)
#
# Using a 5- or 7-point stencil and this improved potential, plot total $E(t)$.

# %%
# (a) monopole + quadrupole potential; compute and plot E(t)

# %% [markdown]
# ### (b)
#
# Does the data provide evidence that Earth's mass distribution is slightly non-spherical? What changed between sections 3 and 4, and which error source did this step address?
#
# *Your answer:*

# %% [markdown]
# ## 5 — Do you believe it?
#
# Three or four sentences. This is the assignment's validation step, and it is what the quiz will ask you about.
#
# Your final plot still is not perfectly flat. Name the three error sources you met in Unit 1, say which one now limits you, and state whether you believe your result demonstrates conservation of energy.
#
# *Trust statement:*

# %% [markdown]
# ## 6 — AI-use log
#
# *Log:*
